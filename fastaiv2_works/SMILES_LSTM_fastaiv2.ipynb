# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcosuff/Marcosuff.github.io/blob/master/fastaiv2_works/SMILES_LSTM_fastaiv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **De novo molecule generation with fastai V2**

# %% [markdown]
# # **Import modules**

# %%
#export
import sys
# !pip install fastai2
! wget -c https://repo.anaconda.com/archive/Anaconda3-2019.10-Linux-x86_64.sh
! bash Anaconda3-2019.10-Linux-x86_64.sh -bfp /usr/local
sys.path.append('/usr/local/lib/python3.7/site-packages')
# !conda install -y -c rdkit rdkit

# %%
#export
import pandas as pd
import numpy as np

from fastai2.text.all import *
#from fastai2.callback import *

from IPython.display import display,HTML

from rdkit.Chem import MolFromSmiles, MolToSmiles, AllChem, SanitizeMol, rdmolops
from rdkit.Chem.Draw import IPythonConsole, MolsToGridImage
from rdkit.Chem.SaltRemover import SaltRemover as saltremover
from rdkit.Chem.MolStandardize.rdMolStandardize import LargestFragmentChooser
from rdkit import rdBase
rdBase.DisableLog('rdApp.error')
rdBase.DisableLog('rdApp.info')

from google.colab import drive

# %%
#export
drive.mount('mydrive')
#sys.path.append('/content/mydrive/My Drive/Generative/mol_utils')
path = Path('/content/mydrive/My Drive/Generative/data')

# %% [markdown]
# # **Import data**

# %%
LM = Path('/content/LM')
LM.mkdir()

# %%
chembl = pd.read_csv(path/'ChEMBL_v2.csv').sample(n=250000)
print(chembl.shape)
db = pd.read_csv(path/'chembl27.csv.gz')
# Out:
# (250000, 3)

# %%
target_name = 'CHEMBL244'
fxa = db[db['target_chembl_id'] == target_name]
print(fxa.shape)
fxa.head()
# Out:
# (6515, 14)
#      doc_id  standard_value  ...               l3 confidence_score
# 22     3476            44.4  ...  Serine protease                8
# 273    6512           180.0  ...  Serine protease                8
# 274    6512           120.0  ...  Serine protease                8
# 288    3476           311.0  ...  Serine protease                8
# 291    3476             6.1  ...  Serine protease                8
#
# [5 rows x 14 columns]

# %% [markdown]
# # **Tokenizing V2**

# %%
#export
class MolTokenizer_v2():

  def tokenize_mols(self, t):
    pat = '(\[.*?\])' # Find special enviroments (e.g., [CH],[NH] etc)
    tokens = []
    t = t.replace('Br','L').replace('Cl','X') # Replace halogens
    atom_list = re.split(pat,t)
    for s in atom_list:
      if s.startswith('['):
        tokens.append(s)
      else:
        tokens += [x for x in list(s)]
    tokens = [x.replace('L','Br').replace('X','Cl') for x in tokens] # Decode halogens
    return [BOS] + tokens

  def __call__(self, items): return (self.tokenize_mols(t) for t in items)

# %%
tk = Tokenizer(MolTokenizer_v2(),rules=[])

# %%
tokens = L(list(chembl.Smiles)).map(tk)
tokens
# Out:
# (#250000) [['xxbos', 'O', '=', 'C', '(', 'N', 'O', ')', 'C', '(', 'C', 'c', '1', 'c', 'c', 'c', 'c', '(', 'O', 'c', '2', 'c', 'c', 'c', 'c', 'c', '2', ')', 'c', '1', ')', 'C', '(', '=', 'O', ')', 'N', 'C', 'C', 'C', 'C', 'c', '1', 'c', 'c', 'c', 'c', 'c', '1'],['xxbos', 'C', 'O', 'C', '[C@H]', '(', 'N', 'C', '(', '=', 'O', ')', 'c', '1', 'c', 'c', '(', 'O', 'C', ')', 'n', 'o', '1', ')', 'C', '(', '=', 'O', ')', 'N', '[C@@H]', '(', 'C', 'O', 'C', ')', 'C', '(', '=', 'O', ')', 'N', '[C@@H]', '(', 'C', 'C', '(', 'C', ')', 'C', ')', 'C', '(', '=', 'O', ')', '[C@@]', '1', '(', 'C', ')', 'C', 'O', '1'],['xxbos', 'C', '[C@]', '1', '2', 'C', '=', 'C', 'C', '(', '=', 'O', ')', 'C', '=', 'C', '1', 'C', 'C', '[C@@H]', '1', 'C', '2', '=', 'C', 'C', '[C@]', '2', '(', 'C', ')', 'C', '(', 'C', '(', '=', 'O', ')', 'C', 'O', ')', '=', 'C', 'C', '[C@@H]', '1', '2'],['xxbos', 'C', 'S', '(', '=', 'O', ')', '(', '=', 'O', ')', 'c', '1', 'c', 'c', 'c', '(', 'N', 'c', '2', 'n', 'c', 'n', 'c', '(', 'O', 'C', '3', 'C', '[C@H]', '4', 'C', 'C', '[C@H]', '(', 'C', '3', ')', 'N', '4', 'S', '(', 'C', ')', '(', '=', 'O', ')', '=', 'O', ')', 'c', '2', '[N+]', '(', '=', 'O', ')', '[O-]', ')', 'c', '(', 'F', ')', 'c', '1'],['xxbos', 'O', '=', 'C', '(', 'C', 'c', '1', 'c', 'c', 'c', '(', 'F', ')', 'c', '(', 'F', ')', 'c', '1', ')', 'N', 'C', '[C@@H]', '1', 'N', '[C@H]', '(', 'C', 'O', ')', '[C@H]', '(', 'O', ')', '[C@@H]', '1', 'O'],['xxbos', 'C', 'N', '1', 'C', 'C', 'C', '(', 'N', 'c', '2', 'c', 'c', 'c', '3', 'n', 'c', 'c', '(', '-', 'c', '4', 'c', 'n', 'n', '(', '-', 'c', '5', 'c', 'n', 'c', 'c', 'n', '5', ')', 'c', '4', ')', 'n', '3', 'n', '2', ')', 'C', 'C', '1'],['xxbos', 'C', 'O', 'c', '1', 'c', 'c', 'c', 'c', '(', '[C@H]', '2', 'C', 'O', 'C', '(', '=', 'O', ')', 'N', '2', 'c', '2', 'c', 'c', 'n', '3', 'n', 'c', 'c', '(', '-', 'c', '4', 'c', 'c', 'c', '(', '-', 'c', '5', 'n', 'c', '[nH]', 'n', '5', ')', 'c', '(', 'F', ')', 'c', '4', ')', 'c', '3', 'n', '2', ')', 'n', '1'],['xxbos', 'O', 'c', '1', 'n', 'n', 'c', '(', 'C', '(', 'F', ')', '(', 'F', ')', 'F', ')', 'c', '2', 'n', 'n', 'n', '(', 'C', 'c', '3', 'c', 'c', 'c', 'c', 'c', '3', 'Cl', ')', 'c', '1', '2'],['xxbos', 'C', 'c', '1', 'c', 'c', 'c', 'c', '(', 'C', ')', 'c', '1', 'O', 'c', '1', 'c', 'c', '(', 'N', 'c', '2', 'c', 'c', 'c', '(', 'C', '#', 'N', ')', 'c', 'c', '2', ')', 'n', 'c', '2', 'n', 'c', 'n', 'n', '1', '2'],['xxbos', 'C', 'C', 'O', 'P', '(', '=', 'O', ')', '(', 'O', 'C', 'C', ')', '[C@@H]', '1', 'C', '[C@H]', '(', 'C', '(', '=', 'O', ')', 'N', 'c', '2', 'c', 'c', '3', 'c', '4', 'c', '(', 'c', 'c', 'c', 'c', '4', 'c', '2', ')', 'C', '(', '=', 'O', ')', 'N', '(', 'C', 'C', 'N', '(', 'C', ')', 'C', ')', 'C', '3', '=', 'O', ')', 'O', 'N', '1', 'C']...]

# %%
num = Numericalize(min_freq = 1, special_toks=[BOS,PAD])
num.setup(tokens)

num.vocab
# Out:
# ['xxbos',
#  'xxpad',
#  'c',
#  'C',
#  '(',
#  ')',
#  '1',
#  'O',
#  '2',
#  '=',
#  'N',
#  'n',
#  '3',
#  'F',
#  '4',
#  '-',
#  '[C@H]',
#  'S',
#  '[C@@H]',
#  'Cl',
#  '/',
#  '[nH]',
#  's',
#  'o',
#  '5',
#  '#',
#  '[N+]',
#  'Br',
#  '\\',
#  '[C@]',
#  '[O-]',
#  '[C@@]',
#  'P',
#  '6',
#  '[n+]',
#  'I',
#  '7',
#  '[N-]',
#  '[P+]',
#  '8',
#  '[s+]',
#  '[P@@]',
#  '[PH]',
#  '[P@]',
#  '[o+]',
#  '[C-]',
#  '[N@+]',
#  '[N@]',
#  '[N@@]',
#  '9',
#  '[N@@+]',
#  'p',
#  '[C+]',
#  '%',
#  '0',
#  '[O+]',
#  '[c+]',
#  '[S@]',
#  '[S@@]',
#  'xxfake',
#  'xxfake',
#  'xxfake',
#  'xxfake',
#  'xxfake']

# %%
coll_repr(num.vocab, 15),len(num.vocab)
# Out:
# ("(#64) ['xxbos','xxpad','c','C','(',')','1','O','2','=','N','n','3','F','4'...]",
#  64)

# %%
#nums10 = tokens[0:10].map(num)
#nums10
num(tokens[1])
# Out:
# TensorText([ 0,  3,  7,  3, 16,  4, 10,  3,  4,  9,  7,  5,  2,  6,  2,  2,  4,  7,
#          3,  5, 11, 23,  6,  5,  3,  4,  9,  7,  5, 10, 18,  4,  3,  7,  3,  5,
#          3,  4,  9,  7,  5, 10, 18,  4,  3,  3,  4,  3,  5,  3,  5,  3,  4,  9,
#          7,  5, 31,  6,  4,  3,  5,  3,  7,  6])

# %% [markdown]
# Let's take a look at some batches. When training a language model, we first concatenate all texts into a big stream and then split it into batches with a defined sequence length.
#
# In the case of SMILES strings, at each epoch the model will recieve `bs` number of mini-batches. But instead of sending long SMILES at each epoch (which would crash the GPU memory), we further split the batches into subarrays with a length equals to `seq_len`. These subarrays are split in a manner as to preserve the order within each SMILES string.

# %%
bs,seq_len = 6,15
d_tokens = np.array([tokens[i*seq_len:(i+1)*seq_len] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>[xxbos, O, =, C, (, N, O, ), C, (, C, c, 1, c, c, c, c, (, O, c, 2, c, c, c, c, c, 2, ), c, 1, ), C, (, =, O, ), N, C, C, C, C, c, 1, c, c, c, c, c, 1]</td>
#       <td>[xxbos, C, O, C, [C@H], (, N, C, (, =, O, ), c, 1, c, c, (, O, C, ), n, o, 1, ), C, (, =, O, ), N, [C@@H], (, C, O, C, ), C, (, =, O, ), N, [C@@H], (, C, C, (, C, ), C, ), C, (, =, O, ), [C@@], 1, (, C, ), C, O, 1]</td>
#       <td>[xxbos, C, [C@], 1, 2, C, =, C, C, (, =, O, ), C, =, C, 1, C, C, [C@@H], 1, C, 2, =, C, C, [C@], 2, (, C, ), C, (, C, (, =, O, ), C, O, ), =, C, C, [C@@H], 1, 2]</td>
#       <td>[xxbos, C, S, (, =, O, ), (, =, O, ), c, 1, c, c, c, (, N, c, 2, n, c, n, c, (, O, C, 3, C, [C@H], 4, C, C, [C@H], (, C, 3, ), N, 4, S, (, C, ), (, =, O, ), =, O, ), c, 2, [N+], (, =, O, ), [O-], ), c, (, F, ), c, 1]</td>
#       <td>[xxbos, O, =, C, (, C, c, 1, c, c, c, (, F, ), c, (, F, ), c, 1, ), N, C, [C@@H], 1, N, [C@H], (, C, O, ), [C@H], (, O, ), [C@@H], 1, O]</td>
#       <td>[xxbos, C, N, 1, C, C, C, (, N, c, 2, c, c, c, 3, n, c, c, (, -, c, 4, c, n, n, (, -, c, 5, c, n, c, c, n, 5, ), c, 4, ), n, 3, n, 2, ), C, C, 1]</td>
#       <td>[xxbos, C, O, c, 1, c, c, c, c, (, [C@H], 2, C, O, C, (, =, O, ), N, 2, c, 2, c, c, n, 3, n, c, c, (, -, c, 4, c, c, c, (, -, c, 5, n, c, [nH], n, 5, ), c, (, F, ), c, 4, ), c, 3, n, 2, ), n, 1]</td>
#       <td>[xxbos, O, c, 1, n, n, c, (, C, (, F, ), (, F, ), F, ), c, 2, n, n, n, (, C, c, 3, c, c, c, c, c, 3, Cl, ), c, 1, 2]</td>
#       <td>[xxbos, C, c, 1, c, c, c, c, (, C, ), c, 1, O, c, 1, c, c, (, N, c, 2, c, c, c, (, C, #, N, ), c, c, 2, ), n, c, 2, n, c, n, n, 1, 2]</td>
#       <td>[xxbos, C, C, O, P, (, =, O, ), (, O, C, C, ), [C@@H], 1, C, [C@H], (, C, (, =, O, ), N, c, 2, c, c, 3, c, 4, c, (, c, c, c, c, 4, c, 2, ), C, (, =, O, ), N, (, C, C, N, (, C, ), C, ), C, 3, =, O, ), O, N, 1, C]</td>
#       <td>[xxbos, O, =, C, (, c, 1, c, c, 2, c, (, s, 1, ), C, C, N, C, 2, ), N, 1, C, C, N, (, S, (, =, O, ), (, =, O, ), c, 2, c, c, c, 3, c, c, (, Cl, ), c, c, c, 3, c, 2, ), C, C, 1]</td>
#       <td>[xxbos, C, O, c, 1, c, c, c, (, C, (, =, O, ), O, c, 2, c, c, c, c, 3, c, c, c, n, c, 2, 3, ), c, c, 1, O, C]</td>
#       <td>[xxbos, C, c, 1, n, c, c, 2, c, c, (, -, c, 3, c, (, Cl, ), c, c, c, c, 3, Cl, ), c, (, N, C, (, =, O, ), c, 3, c, c, o, c, 3, ), n, c, 2, n, 1]</td>
#       <td>[xxbos, C, N, 1, C, 2, C, (, =, O, ), c, 3, c, c, c, c, c, 3, C, 1, C, 1, =, C, 2, C, (, =, O, ), c, 2, c, c, c, c, c, 2, C, 1, =, O]</td>
#       <td>[xxbos, C, C, (, C, ), O, C, C, (, =, O, ), N, 1, c, 2, c, c, c, c, c, 2, C, C, c, 2, c, c, c, (, N, C, (, =, O, ), O, C, (, C, ), C, ), c, c, 2, 1]</td>
#     </tr>
#     <tr>
#       <td>[xxbos, C, C, (, C, ), [P+], (, C, c, 1, c, c, c, (, C, c, 2, c, c, c, (, C, [P+], (, c, 3, c, c, c, c, c, 3, ), (, c, 3, c, c, c, c, c, 3, ), C, (, C, ), C, ), c, c, 2, ), c, c, 1, ), (, c, 1, c, c, c, c, c, 1, ), c, 1, c, c, c, c, c, 1]</td>
#       <td>[xxbos, F, c, 1, c, c, c, c, c, 1, N, C, 1, C, C, N, C, C, 1]</td>
#       <td>[xxbos, C, O, c, 1, c, c, c, (, N, C, (, =, O, ), c, 2, c, c, (, Cl, ), c, c, c, 2, O, ), c, c, 1]</td>
#       <td>[xxbos, C, c, 1, c, c, c, (, S, (, =, O, ), (, =, O, ), C, C, (, =, O, ), N, c, 2, n, n, c, (, C, ), s, 2, ), c, c, 1]</td>
#       <td>[xxbos, O, c, 1, c, c, c, (, /, N, =, C, /, c, 2, c, c, c, 3, c, c, c, c, c, 3, c, 2, ), c, c, 1]</td>
#       <td>[xxbos, C, C, n, 1, c, c, (, -, c, 2, c, c, c, (, -, c, 3, c, 4, c, (, n, n, 3, C, ), C, C, c, 3, c, n, c, (, N, c, 5, c, c, c, (, C, (, =, O, ), O, ), c, c, 5, O, C, ), n, c, 3, -, 4, ), c, c, 2, ), c, n, 1]</td>
#       <td>[xxbos, C, C, O, C, (, =, O, ), N, C, (, =, O, ), C, O, C, (, =, O, ), C, C, C, S, c, 1, n, c, 2, c, c, c, c, c, 2, s, 1]</td>
#       <td>[xxbos, C, C, N, (, C, C, ), c, 1, c, c, c, (, N, c, 2, c, c, c, (, C, C, c, 3, c, c, c, (, Cl, ), c, (, Cl, ), c, 3, ), c, c, 2, ), c, (, C, (, =, O, ), O, ), c, 1]</td>
#       <td>[xxbos, C, N, C, c, 1, c, c, c, c, c, 1, O, c, 1, c, c, c, (, Cl, ), c, c, 1]</td>
#       <td>[xxbos, C, c, 1, c, c, c, (, N, C, (, =, O, ), c, 2, c, (, N, 3, C, (, =, O, ), c, 4, c, c, c, c, c, 4, C, 3, =, O, ), c, (, C, #, N, ), c, 3, n, 2, C, C, C, 3, ), c, c, 1]</td>
#       <td>[xxbos, C, C, C, C, c, 1, c, c, c, (, N, C, (, =, O, ), N, S, (, =, O, ), (, =, O, ), c, 2, c, c, c, (, C, ), c, c, 2, ), c, c, 1]</td>
#       <td>[xxbos, C, (, =, N, /, n, 1, c, n, n, c, 1, ), \, c, 1, c, n, (, C, c, 2, c, c, c, c, c, 2, ), c, 2, c, c, c, c, c, 1, 2]</td>
#       <td>[xxbos, O, =, C, (, C, O, C, (, =, O, ), C, O, c, 1, c, c, c, c, (, Br, ), c, 1, ), N, c, 1, c, c, c, (, F, ), c, c, 1, F]</td>
#       <td>[xxbos, C, c, 1, c, c, n, c, (, C, C, N, C, (, =, O, ), c, 2, c, c, 3, c, c, c, c, (, N, 4, C, C, N, (, C, C, c, 5, c, c, c, c, n, 5, ), C, C, 4, ), c, 3, o, 2, ), n, 1]</td>
#       <td>[xxbos, C, C, (, c, 1, c, c, c, (, -, c, 2, c, c, c, c, c, 2, ), c, c, 1, ), N, (, O, ), C, (, N, ), =, O]</td>
#     </tr>
#     <tr>
#       <td>[xxbos, C, c, 1, c, s, c, (, N, C, (, =, O, ), c, 2, c, c, c, n, c, 2, Cl, ), n, 1]</td>
#       <td>[xxbos, C, C, (, C, N, C, (, =, O, ), c, 1, c, c, c, (, F, ), c, c, 1, Cl, ), N, 1, C, C, C, C, 1]</td>
#       <td>[xxbos, N, =, C, (, N, ), c, 1, c, c, c, (, -, c, 2, [nH], c, 3, c, c, (, C, (, =, N, ), N, ), c, c, c, 3, c, 2, -, c, 2, c, c, c, c, c, 2, ), c, c, 1]</td>
#       <td>[xxbos, C, C, N, (, C, C, (, =, O, ), N, c, 1, c, (, F, ), c, c, c, c, 1, F, ), C, (, =, O, ), C, 1, C, C, C, O, 1]</td>
#       <td>[xxbos, C, N, 1, C, C, (, =, O, ), N, (, C, C, N, 2, C, (, =, O, ), c, 3, c, 4, c, (, c, (, O, ), c, (, =, O, ), n, 3, C, 2, 3, C, C, C, 2, C, C, 2, 3, ), C, (, =, O, ), N, (, C, c, 2, c, c, c, (, F, ), c, (, Cl, ), c, 2, ), C, C, 4, ), C, 1, =, O]</td>
#       <td>[xxbos, C, C, C, c, 1, c, (, C, O, c, 2, c, c, c, (, C, (, =, O, ), C, C, C, C, C, C, c, 3, n, n, n, [nH], 3, ), c, c, 2, ), c, c, c, (, C, (, C, ), =, O, ), c, 1, O]</td>
#       <td>[xxbos, C, C, C, C, n, 1, c, (, -, c, 2, c, c, c, (, O, C, ), c, c, 2, ), n, c, 2, c, c, (, C, (, F, ), (, F, ), F, ), c, c, c, 2, 1]</td>
#       <td>[xxbos, O, =, C, (, N, C, (, =, O, ), c, 1, c, c, c, c, c, 1, ), N, c, 1, c, c, (, N, 2, C, (, =, O, ), C, 3, =, C, (, C, C, C, C, 3, ), C, 2, =, O, ), c, c, c, 1, Cl]</td>
#       <td>[xxbos, C, C, C, C, c, 1, n, n, (, -, c, 2, c, c, c, c, c, 2, [N+], (, =, O, ), [O-], ), c, (, C, (, =, O, ), O, ), c, 1, C, c, 1, c, c, c, (, -, c, 2, c, c, c, c, c, 2, -, c, 2, n, n, [nH], n, 2, ), c, c, 1]</td>
#       <td>[xxbos, C, n, 1, n, c, c, c, 1, -, c, 1, c, c, c, 2, c, (, c, 1, ), /, C, (, =, C, /, c, 1, c, c, c, [nH], 1, ), C, (, =, O, ), N, 2]</td>
#       <td>[xxbos, C, C, (, C, ), N, c, 1, n, c, (, Cl, ), n, c, (, N, [C@H], (, C, ), c, 2, c, c, c, c, c, 2, ), n, 1]</td>
#       <td>[xxbos, C, C, 1, (, C, ), C, C, 1, (, C, #, N, ), N, C, (, =, O, ), [C@@H], (, N, ), C, c, 1, c, c, c, s, 1]</td>
#       <td>[xxbos, C, C, (, C, ), c, 1, c, c, c, c, (, [C@@H], (, C, ), C, (, =, O, ), N, C, C, C, N, (, C, ), C, ), c, 1]</td>
#       <td>[xxbos, C, C, (, C, ), (, C, ), N, C, (, =, O, ), [C@@H], 1, C, N, (, C, (, C, ), (, C, ), c, 2, c, c, c, n, c, 2, ), C, C, N, 1, C, [C@@H], (, O, ), C, [C@@H], (, C, c, 1, c, c, c, c, c, 1, ), C, (, =, O, ), N, [C@H], 1, c, 2, c, c, c, c, c, 2, C, [C@H], 1, O]</td>
#       <td>[xxbos, C, [C@H], (, C, =, O, ), [C@@H], 1, C, C, [C@], 2, (, C, (, =, O, ), O, ), C, C, [C@], 3, (, C, ), [C@H], (, C, C, [C@@H], 4, [C@@], 5, (, C, ), C, C, [C@H], (, O, ), C, (, C, ), (, C, ), [C@@H], 5, C, C, [C@], 4, 3, C, ), [C@@H], 1, 2]</td>
#     </tr>
#     <tr>
#       <td>[xxbos, C, n, 1, c, 2, c, (, c, (, =, O, ), [nH], c, 1, =, O, ), C, (, c, 1, c, c, (, F, ), c, c, (, C, (, F, ), (, F, ), F, ), c, 1, ), C, 1, =, C, (, N, 2, ), c, 2, c, c, c, c, c, 2, C, 1, =, O]</td>
#       <td>[xxbos, C, C, C, 1, (, C, C, ), C, (, =, O, ), N, (, C, O, C, (, =, O, ), c, 2, c, c, c, c, c, 2, ), C, 1, S, c, 1, c, c, c, c, c, 1]</td>
#       <td>[xxbos, C, C, O, C, (, =, O, ), /, C, (, O, ), =, C, /, C, (, =, O, ), c

# %%
bs,seq_len = 4,5
d_tokens = np.array([tokens[i*12:i*12+seq_len] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>[xxbos, O, =, C, (, N, O, ), C, (, C, c, 1, c, c, c, c, (, O, c, 2, c, c, c, c, c, 2, ), c, 1, ), C, (, =, O, ), N, C, C, C, C, c, 1, c, c, c, c, c, 1]</td>
#       <td>[xxbos, C, O, C, [C@H], (, N, C, (, =, O, ), c, 1, c, c, (, O, C, ), n, o, 1, ), C, (, =, O, ), N, [C@@H], (, C, O, C, ), C, (, =, O, ), N, [C@@H], (, C, C, (, C, ), C, ), C, (, =, O, ), [C@@], 1, (, C, ), C, O, 1]</td>
#       <td>[xxbos, C, [C@], 1, 2, C, =, C, C, (, =, O, ), C, =, C, 1, C, C, [C@@H], 1, C, 2, =, C, C, [C@], 2, (, C, ), C, (, C, (, =, O, ), C, O, ), =, C, C, [C@@H], 1, 2]</td>
#       <td>[xxbos, C, S, (, =, O, ), (, =, O, ), c, 1, c, c, c, (, N, c, 2, n, c, n, c, (, O, C, 3, C, [C@H], 4, C, C, [C@H], (, C, 3, ), N, 4, S, (, C, ), (, =, O, ), =, O, ), c, 2, [N+], (, =, O, ), [O-], ), c, (, F, ), c, 1]</td>
#       <td>[xxbos, O, =, C, (, C, c, 1, c, c, c, (, F, ), c, (, F, ), c, 1, ), N, C, [C@@H], 1, N, [C@H], (, C, O, ), [C@H], (, O, ), [C@@H], 1, O]</td>
#     </tr>
#     <tr>
#       <td>[xxbos, C, c, 1, n, c, c, 2, c, c, (, -, c, 3, c, (, Cl, ), c, c, c, c, 3, Cl, ), c, (, N, C, (, =, O, ), c, 3, c, c, o, c, 3, ), n, c, 2, n, 1]</td>
#       <td>[xxbos, C, N, 1, C, 2, C, (, =, O, ), c, 3, c, c, c, c, c, 3, C, 1, C, 1, =, C, 2, C, (, =, O, ), c, 2, c, c, c, c, c, 2, C, 1, =, O]</td>
#       <td>[xxbos, C, C, (, C, ), O, C, C, (, =, O, ), N, 1, c, 2, c, c, c, c, c, 2, C, C, c, 2, c, c, c, (, N, C, (, =, O, ), O, C, (, C, ), C, ), c, c, 2, 1]</td>
#       <td>[xxbos, C, C, (, C, ), [P+], (, C, c, 1, c, c, c, (, C, c, 2, c, c, c, (, C, [P+], (, c, 3, c, c, c, c, c, 3, ), (, c, 3, c, c, c, c, c, 3, ), C, (, C, ), C, ), c, c, 2, ), c, c, 1, ), (, c, 1, c, c, c, c, c, 1, ), c, 1, c, c, c, c, c, 1]</td>
#       <td>[xxbos, F, c, 1, c, c, c, c, c, 1, N, C, 1, C, C, N, C, C, 1]</td>
#     </tr>
#     <tr>
#       <td>[xxbos, C, c, 1, c, c, c, (, N, C, (, =, O, ), c, 2, c, (, N, 3, C, (, =, O, ), c, 4, c, c, c, c, c, 4, C, 3, =, O, ), c, (, C, #, N, ), c, 3, n, 2, C, C, C, 3, ), c, c, 1]</td>
#       <td>[xxbos, C, C, C, C, c, 1, c, c, c, (, N, C, (, =, O, ), N, S, (, =, O, ), (, =, O, ), c, 2, c, c, c, (, C, ), c, c, 2, ), c, c, 1]</td>
#       <td>[xxbos, C, (, =, N, /, n, 1, c, n, n, c, 1, ), \, c, 1, c, n, (, C, c, 2, c, c, c, c, c, 2, ), c, 2, c, c, c, c, c, 1, 2]</td>
#       <td>[xxbos, O, =, C, (, C, O, C, (, =, O, ), C, O, c, 1, c, c, c, c, (, Br, ), c, 1, ), N, c, 1, c, c, c, (, F, ), c, c, 1, F]</td>
#       <td>[xxbos, C, c, 1, c, c, n, c, (, C, C, N, C, (, =, O, ), c, 2, c, c, 3, c, c, c, c, (, N, 4, C, C, N, (, C, C, c, 5, c, c, c, c, n, 5, ), C, C, 4, ), c, 3, o, 2, ), n, 1]</td>
#     </tr>
#     <tr>
#       <td>[xxbos, C, C, C, C, n, 1, c, (, -, c, 2, c, c, c, (, O, C, ), c, c, 2, ), n, c, 2, c, c, (, C, (, F, ), (, F, ), F, ), c, c, c, 2, 1]</td>
#       <td>[xxbos, O, =, C, (, N, C, (, =, O, ), c, 1, c, c, c, c, c, 1, ), N, c, 1, c, c, (, N, 2, C, (, =, O, ), C, 3, =, C, (, C, C, C, C, 3, ), C, 2, =, O, ), c, c, c, 1, Cl]</td>
#       <td>[xxbos, C, C, C, C, c, 1, n, n, (, -, c, 2, c, c, c, c, c, 2, [N+], (, =, O, ), [O-], ), c, (, C, (, =, O, ), O, ), c, 1, C, c, 1, c, c, c, (, -, c, 2, c, c, c, c, c, 2, -, c, 2, n, n, [nH], n, 2, ), c, c, 1]</td>
#       <td>[xxbos, C, n, 1, n, c, c, c, 1, -, c, 1, c, c, c, 2, c, (, c, 1, ), /, C, (, =, C, /, c, 1, c, c, c, [nH], 1, ), C, (, =, O, ), N, 2]</td>
#       <td>[xxbos, C, C, (, C, ), N, c, 1, n, c, (, Cl, ), n, c, (, N, [C@H], (, C, ), c, 2, c, c, c, c, c, 2, ), n, 1]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Creating DataLoaders**

# %% [markdown]
# **LMdataLoader**

# %% [markdown]
# It's simple to create a dataloader using LMdataLoader

# %%
doc(LMDataLoader)
# Out:
# LMDataLoader(dataset, lens=None, cache=2, bs=64, seq_len=72, num_workers=0, shuffle=False, verbose=False, do_setup=True, pin_memory=False, timeout=0, batch_size=None, drop_last=False, indexed=None, n=None, device=None, *, wif=None, before_iter=None, after_item=None, before_batch=None, after_batch=None, after_iter=None, create_batches=None, create_item=None, create_batch=None, retain=None, get_idxs=None, sample=None, shuffle_fn=None, do_batch=None)
# A `DataLoader` suitable for language modeling
#
# To get a prettier result with hyperlinks to source code and documentation, install nbdev: pip install nbdev

# %%
dls = LMDataLoader(tokens.map(num))

# %%
dls

# %%
it = iter(dl)
x1,y1 = next(it)
x2,y2 = next(it)

# %% [markdown]
# As we can see, the first row of the first batche continues on the first row of the next batch. This happens because we split the whole stream of SMILES string using `seq_len`. This way, we preserve the order within the SMILES string.

# %%
' '.join(num.vocab[o] for o in x1[0][:])
# Out:
# 'xxbos C c 1 c c ( - c 2 c s c ( N = C ( N ) N ) n 2 ) c n 1 C xxeos xxbos Br c 1 c c c c ( N c 2 n c n c 3 c c n c c 2 3 ) c 1 N C C N 1 C C O C C 1 xxeos xxbos C O'

# %%
' '.join(num.vocab[o] for o in x2[0][:])
# Out:
# 'c 1 c ( O ) c c ( O ) c ( C ( = N ) C c 2 c c c ( O ) c c 2 ) c 1 O xxeos xxbos C C O C ( = O ) c 1 c c 2 c c ( C ( = O ) O ) c c c 2 [nH] 1 xxeos xxbos C C ( = O'

# %%
' '.join(num.vocab[o] for o in x[2][:])
# Out:
# '[C@@H] ( C ( = O ) O ) N 1 C ( = O ) C ( = C ( c 2 c c c c c 2 ) c 2 c c c c c 2 ) S C 1 = S xxeos xxbos C = C 1 [C@@H] ( O C ( = O ) C [C@H] ( c 2 c c c c c 2 ) N ('

# %%
MolFromSmiles('COc1c(O)cc(O)c(C(=N)Cc2ccc(O)cc2)c1O')

# %% [markdown]
# **DataBlock**

# %% [markdown]
# We can also use the DataBlock API:

# %% [markdown]
# ps> if the text columns isn't called "text", remember to pass ` res_col_name = text_column`. Otherwise, it will return an AttributeError

# %%
d_block = DataBlock(blocks=TextBlock.from_df('Smiles',res_col_name='Smiles',is_lm=True, # Pass is_lm = True since we are training a language model.
                                             tok=MolTokenizer_v2(), rules=[], vocab=num.vocab), # Our tokenizer goes here and we define a minimum of 1
                    get_x=ColReader('Smiles'),
                    splitter=RandomSplitter(0.1)) # Randomply split the data (e.g., 90% for training and 10% for validation)

# %%
dls = d_block.dataloaders(chembl, bs=64, seq_len=30)
dls.show_batch(max_n=2)

# %% [markdown]
# **Mid-level API**

# %% [markdown]
# First we define the transformations we want to apply. For language models, the basic transformations would be tokenization and numericalization.
#
# We can put all transformations together using the Pipeline class

# %%
doc(Pipeline)
# Out:
# Pipeline(funcs=None, split_idx=None)
# A pipeline of composed (for encode/decode) transforms, setup with types
#
# To get a prettier result with hyperlinks to source code and documentation, install nbdev: pip install nbdev

# %%
tfms = Pipeline([tk, num])

# %%
t = 'c1ccccc1'
t_num = tfms(t)

# %%
tfms.decode(t_num)
# Out:
# 'xxbos c 1 c c c c c 1 xxeos'

# %% [markdown]
# `Pipeline` is very useful, but it can't setup the transformations. To properly call `setup` and get the dataset ready, we will use `TfmdLists`

# %%
doc(TfmdLists)
# Out:
# TfmdLists(items, tfms, use_list=None, do_setup=True, split_idx=None, train_setup=True, splits=None, types=None, verbose=False, dl_type=None)
# A `Pipeline` of `tfms` applied to a collection of `items`
#
# To get a prettier result with hyperlinks to source code and documentation, install nbdev: pip install nbdev

# %%
doc(Tokenizer.from_df)
# Out:
# Tokenizer.from_df(text_cols, tok=None, rules=None, sep=' ', n_workers=2, mark_fields=None, res_col_name='text', **kwargs)
# None
#
# To get a prettier result with hyperlinks to source code and documentation, install nbdev: pip install nbdev

# %%
tfms = [Tokenizer(tok=MolTokenizer_v2(), rules=[]),
        Numericalize(min_freq=1, special_toks = [UNK, PAD, BOS, EOS])]

tfms = [attrgetter("text"),Tokenizer.from_df(tok=MolTokenizer_v2(), rules=[], text_cols='Smiles', res_col_name = 'Smiles'),
        Numericalize(min_freq=1, special_toks = [UNK, PAD, BOS, EOS])]

# %%
attrgetter
# Out:
# operator.attrgetter

# %%
tls = TfmdLists(chembl,tfms = tfms, splits=splits)

# %% [markdown]
# **For some reason using Tokenizer.from_df and Numericalization throws an UnhashbleError**.
# Solved by passin attrgetter('Smiles')

# %%
t = tls[7]; t[:20]
# Out:
# tensor([ 2,  4,  8,  5,  9,  5,  5,  5,  5,  6,  4, 12,  4, 11,  6,  4,  4,  4,
#          6,  4])

# %%
tls.decode(t)
# Out:
# 'xxbos C O c 1 c c c c ( C N C 2 ( C C C ( C ) ( C ) C ) C ( = O ) C ( C 3 = N S ( = O ) ( = O ) c 4 c c ( N S ( C ) ( = O ) = O ) c c c 4 N 3 ) = C ( O ) c 3 c c c c c 3 2 ) c 1 xxeos'

# %%
tls.show(t)
# Out:
# xxbos C O c 1 c c c c ( C N C 2 ( C C C ( C ) ( C ) C ) C ( = O ) C ( C 3 = N S ( = O ) ( = O ) c 4 c c ( N S ( C ) ( = O ) = O ) c c c 4 N 3 ) = C ( O ) c 3 c c c c c 3 2 ) c 1 xxeos

# %% [markdown]
# We can access the training and validation sets:

# %%
tls.train[0] # We
# Out:
# TensorText([ 2,  5,  4,  9,  4,  4,  6, 20,  4, 11,  4, 29,  4,  6, 12, 10,  5,  6,
#         12,  7, 12,  7, 15, 11,  7,  4, 15,  9,  5,  3])

# %%
tls.valid[0]
# Out:
# TensorText([ 2, 12, 10,  5,  6, 12,  7, 12,  5,  5,  5, 14,  6, 12,  5,  6, 10,  8,
#          7,  5, 14,  6, 12,  5,  6, 10,  8,  7,  5, 14,  6, 12,  7,  5,  6, 10,
#          8,  7, 12, 16,  6,  5,  5,  6, 10,  8,  7, 12, 16,  6,  5,  5,  5, 12,
#          5,  6, 10, 12,  7, 12,  7,  5,  6, 10,  8,  7,  8,  7,  5,  6, 10,  8,
#          7,  8,  7,  5,  6, 10,  8,  7,  8,  7,  5,  6, 10,  8,  7,  8,  3])

# %% [markdown]
# We can directly convert `TfmdLists` to dataloaders using the dataloaders method.

# %%
dls = tls.dataloaders(bs=64,seq_len=30,dl_type=LMDataLoader)

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos C C C C ( C ) ( C ) C ( = O ) N [C@H] 1 C C C C N C 1 = O xxeos xxbos</td>
#       <td>C C C C ( C ) ( C ) C ( = O ) N [C@H] 1 C C C C N C 1 = O xxeos xxbos O</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>c 1 c c c c ( N 2 C C C ( O c 3 c c c n c 3 ) C C 2 ) c 1 F</td>
#       <td>1 c c c c ( N 2 C C C ( O c 3 c c c n c 3 ) C C 2 ) c 1 F xxeos</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2 C ) c 1 xxeos xxbos O = C ( C C N C ( = O ) [C@H] ( C c 1 c c c ( - c</td>
#       <td>C ) c 1 xxeos xxbos O = C ( C C N C ( = O ) [C@H] ( C c 1 c c c ( - c 2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1 ) C ( = O ) N 1 C C C [C@H] 1 C O xxeos xxbos C [C@H] 1 C C [C@@H] ( N C c 2 c</td>
#       <td>) C ( = O ) N 1 C C C [C@H] 1 C O xxeos xxbos C [C@H] 1 C C [C@@H] ( N C c 2 c c</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>C C S c 1 n n c 3 n 1 S ( = O ) ( = O ) c 1 c c c c c 1 N 3</td>
#       <td>C S c 1 n n c 3 n 1 S ( = O ) ( = O ) c 1 c c c c c 1 N 3 c</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>= O ) C 1 ( C ) C xxeos xxbos C c 1 c c c ( O c 2 n c 3 c c c c c 3</td>
#       <td>O ) C 1 ( C ) C xxeos xxbos C c 1 c c c ( O c 2 n c 3 c c c c c 3 n</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>c ( C N ) c ( = O ) o c 3 c 2 [C@@H] ( O C ( = O ) [C@@] 2 3 C C [C@] (</td>
#       <td>( C N ) c ( = O ) o c 3 c 2 [C@@H] ( O C ( = O ) [C@@] 2 3 C C [C@] ( C</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>c 2 c c ( O C ) c c ( O C ) c 2 ) C [C@@H] ( O ) C [C@@H] 1 O xxeos xxbos C C</td>
#       <td>2 c c ( O C ) c c ( O C ) c 2 ) C [C@@H] ( O ) C [C@@H] 1 O xxeos xxbos C C c</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>c c c ( [C@@] 2 3 O c 4 c c ( O C ) c c ( O C ) c 4 [C@] 2 ( O ) [C@H]</td>
#       <td>c c ( [C@@] 2 3 O c 4 c c ( O C ) c c ( O C ) c 4 [C@] 2 ( O ) [C@H] (</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Training**

# %%
cut = int(len(chembl)*0.9)
cut
# Out:
# 225000

# %%
defaults.text_spec_tok
spec_toks = [BOS, PAD]

# %%
splits = [range(cut), range(cut,len(chembl))] # Split data into train and valid sets (90/10)
tfms = [attrgetter("Smiles"),Tokenizer.from_df(text_cols='Smiles',tok=MolTokenizer_v2(),rules=[],res_col_name='Smiles'),
        Numericalize(min_freq = 1, special_toks=spec_toks)]
dst = Datasets(chembl, tfms=[tfms], splits = splits, dl_type=LMDataLoader)

# %%
dls = dst.dataloaders(bs=64,seq_len=30)

# %%
dls.vocab = [x for x in dls.vocab if x != 'xxfake']
dls.vocab
# Out:
# ['xxbos',
#  'xxpad',
#  'c',
#  'C',
#  '(',
#  ')',
#  '1',
#  'O',
#  '2',
#  '=',
#  'N',
#  'n',
#  '3',
#  'F',
#  '4',
#  '-',
#  '[C@H]',
#  'S',
#  '[C@@H]',
#  'Cl',
#  '/',
#  '[nH]',
#  's',
#  'o',
#  '5',
#  '#',
#  '[N+]',
#  'Br',
#  '\\',
#  '[C@]',
#  '[O-]',
#  '[C@@]',
#  'P',
#  '6',
#  '[n+]',
#  'I',
#  '7',
#  '[N-]',
#  '[P+]',
#  '8',
#  '[s+]',
#  '[P@@]',
#  '[PH]',
#  '[P@]',
#  '[o+]',
#  '[C-]',
#  '[N@+]',
#  '[N@]',
#  '[N@@]',
#  '9',
#  '[N@@+]',
#  'p',
#  '[C+]',
#  '%',
#  '0',
#  '[O+]',
#  '[c+]',
#  '[S@]',
#  '[S@@]']

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos C c 1 c c n c 2 c 1 c ( = O ) c 1 c c c c c 1 n 2 C xxbos F c</td>
#       <td>C c 1 c c n c 2 c 1 c ( = O ) c 1 c c c c c 1 n 2 C xxbos F c 1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>c 1 ) = N \ C C 2 xxbos C [C@H] 1 C N = C ( N c 2 c c c c c 2 ) N 1</td>
#       <td>1 ) = N \ C C 2 xxbos C [C@H] 1 C N = C ( N c 2 c c c c c 2 ) N 1 C</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C ( F ) ( F ) F ) N 1 C C N ( C c 2 c c c c ( N 3 C C O C C</td>
#       <td>( F ) ( F ) F ) N 1 C C N ( C c 2 c c c c ( N 3 C C O C C 3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c 3 ) n c n c 2 1 ) c 1 c c c ( Br ) c c 1 xxbos C S C C C C ( C</td>
#       <td>3 ) n c n c 2 1 ) c 1 c c c ( Br ) c c 1 xxbos C S C C C C ( C c</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>) c c 1 xxbos C C N ( C C ) C C C N C c 1 c o c ( - c 2 c c c (</td>
#       <td>c c 1 xxbos C C N ( C C ) C C C N C c 1 c o c ( - c 2 c c c ( F</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>C C ( = O ) C C C C C [C@H] ( N C ( = O ) C 1 C C N ( C ) C C 1</td>
#       <td>C ( = O ) C C C C C [C@H] ( N C ( = O ) C 1 C C N ( C ) C C 1 )</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>( C ( F ) ( F ) F ) c 1 ) c 1 c c c c c 1 xxbos C C ( C ) c 1 c</td>
#       <td>C ( F ) ( F ) F ) c 1 ) c 1 c c c c c 1 xxbos C C ( C ) c 1 c c</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>C [C@@H] ( N C ( = O ) c 1 c c ( C ( = O ) N C c 2 c n c c n 2 )</td>
#       <td>[C@@H] ( N C ( = O ) c 1 c c ( C ( = O ) N C c 2 c n c c n 2 ) n</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>C 3 ) c c 2 ) = N O 1 xxbos O = C ( N O ) c 1 c c 2 c ( s 1 ) C</td>
#       <td>3 ) c c 2 ) = N O 1 xxbos O = C ( N O ) c 1 c c 2 c ( s 1 ) C N</td>
#     </tr>
#   </tbody>
# </table>

# %%
#export
d_block = DataBlock(blocks=TextBlock.from_df('Smiles',res_col_name='Smiles',is_lm=True, # Pass is_lm = True since we are training a language model.
                                             tok=MolTokenizer_v2(), rules=[], min_freq=1), # Our tokenizer goes here and we define a minimum of 1
                    get_x=ColReader('Smiles'),
                    splitter=RandomSplitter(0.1)) # Randomply split the data (e.g., 90% for training and 10% for validation)
dls = d_block.dataloaders(chembl, bs=64, seq_len=30)
dls.show_batch(max_n=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos C C N ( C C ) C C N 1 N = C ( c 2 c c c ( Br ) c c 2 ) C C</td>
#       <td>C C N ( C C ) C C N 1 N = C ( c 2 c c c ( Br ) c c 2 ) C C 2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>F ) c c c 2 S 1 xxeos xxbos C O c 1 c c ( - c 2 n c n ( C ) c 2 - c</td>
#       <td>) c c c 2 S 1 xxeos xxbos C O c 1 c c ( - c 2 n c n ( C ) c 2 - c 2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>O = C ( C ( F ) F ) N 1 C C c 2 n c ( N 3 C C C ( O c 4 c c</td>
#       <td>= C ( C ( F ) F ) N 1 C C c 2 n c ( N 3 C C C ( O c 4 c c c</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>) c c 3 ) n n 1 2 xxeos xxbos C O c 1 c c c ( / C = C / C ( = N / N</td>
#       <td>c c 3 ) n n 1 2 xxeos xxbos C O c 1 c c c ( / C = C / C ( = N / N C</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>c 1 c c ( - c 2 c s c ( N c 3 c c c c ( C ) c 3 ) n 2 ) c c</td>
#       <td>1 c c ( - c 2 c s c ( N c 3 c c c c ( C ) c 3 ) n 2 ) c c n</td>
#     </tr>
#   </tbody>
# </table>

# %%
#export
config = awd_lstm_lm_config.copy()
config.update({'n_hid':512})

# %%
learn = language_model_learner(dls,AWD_LSTM,config=config,drop_mult=0.1,pretrained=False,metrics=[accuracy, Perplexity()])

# %%
learn.fit(5,1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.839070</td>
#       <td>2.500424</td>
#       <td>0.255903</td>
#       <td>12.187662</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.634375</td>
#       <td>2.365330</td>
#       <td>0.334201</td>
#       <td>10.647552</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.483859</td>
#       <td>2.190485</td>
#       <td>0.358854</td>
#       <td>8.939546</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.343545</td>
#       <td>2.005993</td>
#       <td>0.417708</td>
#       <td>7.433473</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.191309</td>
#       <td>1.811669</td>
#       <td>0.469097</td>
#       <td>6.120653</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Defining callbacks**

# %% [markdown]
# When training a generative chemistry-based model, we are interested in generating valid molecules. By training the previous model long enought we might probably achieve very high accuracies, which translates that the model is doing a great job in predicting the next character in a SMILES string. In fact, this is an indirect evaluation of how good the model is in generating valid molecules.
#
# Usually we need more flexibility than this. For instance, we might want to inspect how many novel molecules (i.e., not present in training set) can be generated after each epoch. We might also ask if the generated molecules are close to an objective, such as a biological target chemical space.
#
# To answer these questions, we can use **callbacks**. Callbacks are customizations applied on the model and the training loop that allow us to do basically anything we want. For starters, let's see if we can create a callback to generate 5 molecules after each epoch.

# %%
#export
class MolSampler_V2(Callback):
  def __init__(self, text:str='', max_size:int=30, temperature:float=1.0, max_mols:int=5):
    super().__init__()
    self.text = text
    self.max_size = max_size
    self.temperature = temperature
    self.max_mols = max_mols

  def sampling(self):
    act = getattr(learn.loss_func, 'activation', noop)

    self.model.reset()    # Reset the model
    stop_index = self.dls.train.vocab.index(BOS)        # Define the stop token
    idxs = self.dls.test_dl([self.text]).items[0].to(self.dls.device)
    nums = self.dls.train_ds.numericalize     # Numericalize (used to decode)
    accum_idxs = []                   # Store predicted tokens

    for _ in range(self.max_size):
      with torch.no_grad(): preds=self.model(idxs[None])[0][-1]
      res = act(preds)

      if self.temperature != 1.: res.pow_(1 / self.temperature)
      idx = torch.multinomial(res, 1).item()
      if idx != stop_index:
        accum_idxs.append(idx)
        idxs = TensorText(idxs.new_tensor([idx]))
      else:
        break
    decoded = ''.join([nums.vocab[o] for o in accum_idxs if nums.vocab[o] not in [BOS, PAD]])  # Decode predicted tokens
    return decoded

  def after_epoch(self):
    self.sampling()
    print([self.sampling() for _ in range(self.max_mols)])

# %%
cbs=[MolSampler_V2(), CSVLogger(), SaveModelCallback(monitor='accuracy')]

learn = language_model_learner(dls, AWD_LSTM, pretrained=False,config=config,path=LM,
                               drop_mult=0.1,metrics=[accuracy, Perplexity()])

# %%
learn.lr_find(num_it=600)
# Out:
# SuggestedLRs(lr_min=0.018478497862815857, lr_steep=6.118806049926206e-05)

# %%
learn.fit_one_cycle(n_epoch=7,lr_max=0.001737800776027143,cbs=cbs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.799168</td>
#       <td>0.781596</td>
#       <td>0.732537</td>
#       <td>2.184957</td>
#       <td>13:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.697538</td>
#       <td>0.682242</td>
#       <td>0.763715</td>
#       <td>1.978308</td>
#       <td>12:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.667708</td>
#       <td>0.648523</td>
#       <td>0.774596</td>
#       <td>1.912713</td>
#       <td>12:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.641927</td>
#       <td>0.624016</td>
#       <td>0.783101</td>
#       <td>1.866408</td>
#       <td>12:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.599877</td>
#       <td>0.598313</td>
#       <td>0.792236</td>
#       <td>1.819047</td>
#       <td>12:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.570850</td>
#       <td>0.582207</td>
#       <td>0.798113</td>
#       <td>1.789985</td>
#       <td>12:51</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.555107</td>
#       <td>0.579299</td>
#       <td>0.799398</td>
#       <td>1.784787</td>
#       <td>12:53</td>
#     </tr>
#   </tbody>
# </table>
# ['CCCCCCCCCCC)OCc1coc2ccccc12', 'O=C1N[C@H](Cc2ccc(OCc3ccccc3)cc2)C', 'N#Cc1ccn(C2CCSCC2)c2nc(N3CCCCC', 'CC(N1CCN(c2ccccc2)CC1)C(=O)N(C', 'CCOc1ccc(C(C)Nc2ncnc3c2ncn3C)n']
# Better model found at epoch 0 with accuracy value: 0.7325373291969299.
# ['CC(C)(C)C(=O)N[C@@H](Cc1cn(C(=O)Nc2', 'COc1ccc(-n2c(CC3CCN(C(=O)Cc4cc', 'Cc1cnc(N)nc1-n1cc2ccnc(-c3ccc4', 'COc1ccc(S(=O)(=O)N(C)C)c(NC(=O', 'COc1ccc(-c2nc3cc(NC(C)=O)ccc3n']
# Better model found at epoch 1 with accuracy value: 0.7637149691581726.
# ['O=[N+]([O-])c1ccc(CNCc2coc(-c3ccco3)', 'C[C@@H](Oc1ccc(Cn2cnc3c(NN)ncnc32)n', 'CNC[C@H]1CN(c2ccc(F)cc2)c2ccccc2S1', 'Cc1ccc(N2C[C@H]3CS(=O)(=O)[C@H](C(=O)O', 'CCCS(=O)(=O)c1ccc(CCC(OCc2ccc(']
# Better model found at epoch 2 with accuracy value: 0.7745956182479858.
# ['COc1cc(C(=O)N2CCC(C(=O)N(C)Cc3', 'CCC(C)C[C@@H](Oc1nc(=O)cc(C)[nH]1)c1cc', 'CCOC(=O)c1c3ccccc3c(-c2ccc(S(N', 'Cc1ccc(C(=O)NCCN(C)Cc2cc(=O)n(', 'CC1=C(C(=O)N2CCN(Cc3cccc([N+](=O)']
# Better model found at epoch 3 with accuracy value: 0.7831006646156311.
# ['CCC(C)c1cn([C@@H]2CCN(C(=O)C3CC3)[C@@H](', 'CNC(=O)CN(CCc1ccccc1)C(=O)COc1', 'Cn1nnc2ccc(-c3cc(NC(=O)N4CC(OC', 'CC(C)(C)OC(=O)Nc1ccc(-c2ccc3c(', 'O=C(N[C@H]1CCOC1)c1cc(OCCNCc2ccc(C']
# Better model found at epoch 4 with accuracy value: 0.7922359108924866.
# ['Cc1cc(N)nc(C)c1CCNC(=O)c1cc2cc', 'CN[C@H]1Cc2cccc(NC(=O)CC)c2[C@@H](c2ccc', 'CN(C)CCCOc1nccc(OCC(CC(C)C)S(C', 'O=C(O)c1cc(Cc2ccccc2)n(CC2CC2)', 'Cc1cc(C)nc(N1CC2CCN(CC(=O)Nc3c']
# Better model found at epoch 5 with accuracy value: 0.798112690448761.
# ['Co1cnc(C(=O)Nc2ccc(S(=O)(=O)N(', 'CS(=O)(=O)NCC(c1ccc2c(c1)OCO2)', 'O=C(NNc1nc(-c2ccc(Cl)cc2)cs1)c1', 'CNC(=O)[C@H]1O[C@@H](n2cnc3c(NCC4CCCCC4', 'O=C([C@H]1CCC[C@@H]1[N+](=O)[O-])N1CCCC1']
# Better model found at epoch 6 with accuracy value: 0.799397885799408.

# %%
learn.save('fit1')

# %%
learn.load('fit1');

# %%
#learner.data.vocab.save(mdl_path/(lm_fns[1] + '.pkl'))
with open(LM/'vocab.txt', 'w') as f:
  for i in dls.vocab:
    f.write(i+'\n')

# %%
learn.export()

# %%
learn_inf = load_learner('/content/LM/export.pkl')

# %%
def sampler_test(model, text, temperature, max_size):
  model.model.reset()
  nums = model.dls.train_ds.numericalize
  idxs = idxs_all = model.dls.test_dl([text]).items[0]#.to(model.dls.device)
  for _ in range(max_size):
  
   # print('begin')
    preds,_ = model.get_preds(dl=[(idxs[None],)])
    res = preds[0][-1]
    if temperature != 1.: res.pow_(1 / temperature)
    idx = torch.multinomial(res, 1).item()
    if idx != 0:
      idxs = idxs_all = torch.cat([idxs_all, idxs.new([idx])])
    else:
      break

  return ''.join([nums.vocab[i] for i in idxs_all if nums.vocab[i] not in [BOS, PAD]])

# %%
# !tar -cvf /content/mydrive/My\ Drive/Blog/fastai_v2_LM.tar.gz LM/*

# %%
mols = [sampler_test(model=learn_inf,text='',temperature=0.7,max_size=120) for _ in range(100)]

# %% [markdown]
# How many **valid** molecules did we generate?

# %%
valid_mols = [x for x in mols if MolFromSmiles(x)]
print('Percentage of valid SMILES:{:.2f}%'.format(100*len(valid_mols)/len(mols)))
# Out:
# Percentage of valid SMILES:100.00%

# %% [markdown]
# How many molecules are **novel** (i.e., not present on the training set)?

# %%
novel_mols = set.difference(set(valid_mols),set(chembl.Smiles))
print('Percentage of novel SMILES:{:.2f}%'.format(100*len(novel_mols)/len(valid_mols)))
# Out:
# Percentage of novel SMILES:99.00%

# %% [markdown]
# And how many unique SMILES do we have?

# %%
unique_mols = set(valid_mols)
print('Percentage of unique SMILES:{:.2f}%'.format(100*len(unique_mols)/len(valid_mols)))
# Out:
# Percentage of unique SMILES:100.00%

# %%
MolsToGridImage(mols = list(map(MolFromSmiles,valid_mols)),maxMols=100,molsPerRow=5,subImgSize=(300,300))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1500x6000 at 0x7F3E5D909C18>

# %% [markdown]
# # **Fine-tuning**

# %% [markdown]
# Now that we have a pretrained model that can generate valid molecules, we are going to fine-tune it to a particular chemical space. In this example, we will use Coagulation Factor Xa as the objective task.

# %%
with open(LM/'vocab.pkl', 'wb') as f:
  pickle.dump(learn.dls.vocab, f)

# %%
fxa.columns
# Out:
# Index(['doc_id', 'standard_value', 'standard_type', 'standard_relation',
#        'pchembl', 'molregno', 'canonical_smiles', 'chembl_id',
#        'target_dictionary', 'target_chembl_id', 'l1', 'l2', 'l3',
#        'confidence_score'],
#       dtype='object')

# %%
d_block = DataBlock(blocks=TextBlock.from_df('canonical_smiles',res_col_name='canonical_smiles',is_lm=True, # Pass is_lm = True since we are training a language model.
                                             tok=MolTokenizer_v2(), rules=[], vocab=vocab_lm), # Our tokenizer goes here and we define a minimum of 1
                    get_x=ColReader('canonical_smiles'),
                    splitter=RandomSplitter(0.1)) # Randomply split the data (e.g., 90% for training and 10% for validation)

# %%
dls_fn = d_block.dataloaders(fxa,bs=64,seq_len=30)

# %%
dls_fn.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos O = C 1 [C@@H] ( N S ( = O ) ( = O ) / C = C / c 2 c c c ( Cl )</td>
#       <td>O = C 1 [C@@H] ( N S ( = O ) ( = O ) / C = C / c 2 c c c ( Cl ) s</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>= C ( N ) c 1 c c c 2 s c c ( C ( C c 3 c c c c c 3 ) C ( =</td>
#       <td>C ( N ) c 1 c c c 2 s c c ( C ( C c 3 c c c c c 3 ) C ( = O</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>( = N ) N ) c 2 ) c c ( C ( F ) ( F ) F ) c 1 xxbos N = C ( N )</td>
#       <td>= N ) N ) c 2 ) c c ( C ( F ) ( F ) F ) c 1 xxbos N = C ( N ) N</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c 1 - c 1 c c c ( C ( = O ) N c 2 c c c ( Cl ) c c 2 C ( = O</td>
#       <td>1 - c 1 c c c ( C ( = O ) N c 2 c c c ( Cl ) c c 2 C ( = O )</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>C C ( C ) C ) c c 2 C ( = O ) O ) c ( C ( = O ) N c 2 c c c</td>
#       <td>C ( C ) C ) c c 2 C ( = O ) O ) c ( C ( = O ) N c 2 c c c (</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>N 3 C C c 4 c ( C ( F ) ( F ) F ) n n ( - c 5 c c c ( O C )</td>
#       <td>3 C C c 4 c ( C ( F ) ( F ) F ) n n ( - c 5 c c c ( O C ) c</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>c c 1 Cl xxbos C C ( C ) ( C ) O C ( = O ) N [C@@H] ( C C C N = C ( N</td>
#       <td>c 1 Cl xxbos C C ( C ) ( C ) O C ( = O ) N [C@@H] ( C C C N = C ( N )</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[nH] c 5 c 4 ) C 3 = O ) c c 2 c 1 xxbos C C O [C@@H] 1 C [C@H] ( C ( = O )</td>
#       <td>c 5 c 4 ) C 3 = O ) c c 2 c 1 xxbos C C O [C@@H] 1 C [C@H] ( C ( = O ) N</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>( C C ( = O ) N [C@@H] ( C C C N C ( = N ) N ) C ( = O ) c 2 n c</td>
#       <td>C C ( = O ) N [C@@H] ( C C C N C ( = N ) N ) C ( = O ) c 2 n c c</td>
#     </tr>
#   </tbody>
# </table>

# %%
fn_path = Path(LM/'fxa_finetune')
fn_path.mkdir()

# %%
pretrained_vocab = '/content/LM/vocab.pkl'
pretrained_wgts = '/content/LM/models/fit1.pth'
fnames = [pretrained_wgts,pretrained_vocab]
#old_vocab = Path('/content/LM/vocab.pkl').load()

# %%
cbs=[MolSampler_V2(), CSVLogger(), SaveModelCallback(monitor='accuracy')]

learn_fn = language_model_learner(dls_fn, AWD_LSTM, pretrained=False,config=config,path=fn_path,
                               drop_mult=0.1,metrics=[accuracy, Perplexity()]).load_pretrained(wgts_fname=fnames[0],vocab_fname=fnames[1])
learn_fn.freeze()

# %%
learn_fn.lr_find(num_it=600)
# Out:
# SuggestedLRs(lr_min=0.020261269807815552, lr_steep=0.10000000149011612)

# %%
learn_fn.fit_one_cycle(n_epoch=7,lr_max=0.012783996760845184,cbs=cbs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.542333</td>
#       <td>0.542068</td>
#       <td>0.817646</td>
#       <td>1.719560</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.493173</td>
#       <td>0.497153</td>
#       <td>0.831431</td>
#       <td>1.644034</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.467240</td>
#       <td>0.479073</td>
#       <td>0.839725</td>
#       <td>1.614577</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.455847</td>
#       <td>0.470287</td>
#       <td>0.843106</td>
#       <td>1.600453</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.453215</td>
#       <td>0.465870</td>
#       <td>0.844993</td>
#       <td>1.593400</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.451828</td>
#       <td>0.463902</td>
#       <td>0.845760</td>
#       <td>1.590267</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.447361</td>
#       <td>0.463549</td>
#       <td>0.845486</td>
#       <td>1.589706</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# ['CC[C@H](C)[C@@H](N)C(=O)Nc1cc(-n2cccc2C', 'Nc1c(Cl)cc(C(=O)NC2CCN(Cc3ccc(Cl', 'Cc1nc2c(c(C(=O)c3cc(OCC(=O)O)c', 'N=C(N)c1cccc(C(=O)N(CCN(Cc2ccc', 'Cn1cc(C(=O)c2ccncc2)cc1-c1cccc']
# Better model found at epoch 0 with accuracy value: 0.8176459074020386.
# ['CN(C)c1ccc(C23CCC(CC2)CN(C(=O)', 'Nc1nc(O)c2ncn([C@@H]3O[C@H](CNCCc4ccccc', 'CC1(C)CC(C(=O)Nc2cccc3c2OCCO3)', 'Nc1ccc(N2CCOCC2=O)cc1', 'CCCC(NC(=O)c1ccccc1C(=O)OC)C(=']
# Better model found at epoch 1 with accuracy value: 0.8314313292503357.
# ['COCC(=O)N1CCC(Oc2ccc(NC(=O)c3c', 'CC(C)C[C@H](NC(=O)c1ccc(Cl)s1)C(=O)', 'CCn1cc(CN(CC(C)C)C(CC(F)(F)F)C', 'COc1ccc(-c2nc(CNC(=O)c3ccncc3)', 'CC(=O)N(Cc1ncc(-c2cc(Oc3c(C)n(']
# Better model found at epoch 2 with accuracy value: 0.839724600315094.
# ['CN1CCN(c2cc(NCCNC(=N)N)nc(N)n2', 'NC(=O)[C@@H]1CCCN1C(=O)C[C@@H](Cc1cccc(C', 'COC(=O)c1c(O)c(Cc2ccccc2)nc2cc', 'O=S(=O)(c1ccc(-n2nc(CNC3CCCC3)', 'CCOC(=O)CNC(=O)c1ccc(-c2cc3cc(']
# Better model found at epoch 3 with accuracy value: 0.8431059718132019.
# ['CC(=O)N1C[C@H](Oc2ncnc3ccn(-c4cnc5', 'N=C(N)c1ccc(CN(C(=O)N[C@H](Cc2cccc', 'COc1cc(CN2CC=C(c3ccc(OC)cc3)CC', 'CC1c2ncCn2c(C(=O)NCc2ccc(-c3cc', 'O=C(NC[C@H]1CN(c2ccc(-n3cccc3)cc2)']
# Better model found at epoch 4 with accuracy value: 0.8449925780296326.
# ['CC(C)C(=O)N(C)c1cccc(CN(C)c2cc', 'CO[C@@H]1CN(CC(=O)Nc2ccc(-n3ccccc3=', 'CO/C(O)=C1\\C(COCCN)=C(N)N(NC(=', 'COc1cccc(C(=O)N[C@@H](c2ccccc2)c2cc', 'Cc1cc(C(NC(=O)OCC(C)(C)C)C(=O)']
# Better model found at epoch 5 with accuracy value: 0.8457598090171814.
# ['NCc1sc2ccccc2c1C(=O)Nc1ccc(NC(', 'CCC(=O)Nc1cccc(-n2c(C(=O)NCc3c', 'CC(=O)[C@@H]1CC[C@H]2C(=O)N(c3ccc(-n4cc', 'FCCNS(=O)(=O)c1ccc(CCN2CCc3cc(', 'CC[C@@]1(N[C@@H]2c(NC(=O)OC)nc(OCCN(C)C']

# %%
learn_fn.save('fit1')

# %%
learn_fn.load('fit1');

# %%
learn_fn.freeze_to(-2)
learn_fn.lr_find(num_it=600)
# Out:
# SuggestedLRs(lr_min=0.0007134003564715386, lr_steep=0.00363078061491251)

# %%
learn_fn.fit_one_cycle(3, slice(3e-3/(2.6**4),3e-3),cbs=cbs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.386780</td>
#       <td>0.378905</td>
#       <td>0.876537</td>
#       <td>1.460684</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.332496</td>
#       <td>0.340168</td>
#       <td>0.889034</td>
#       <td>1.405183</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.302684</td>
#       <td>0.332967</td>
#       <td>0.890946</td>
#       <td>1.395101</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# ['CN(CC1=CCCN(c2ccc(-n3ccccc3=O)', 'O=C(CCS(=O)(=O)c1ccc2cc(Cl)ccc2', 'COC(=O)CSc1[nH]cnc2ncn(-c3ccc(N)c', 'CCCCN(C)C(=O)[C@@H](C)N1CC[C@H](NS(=O)(', 'N=C(N)NCCC1(Nc2cccc(C(=O)NC[C@H](N']
# Better model found at epoch 0 with accuracy value: 0.8765367865562439.
# ['O=C(Nc1ccc(Cl)cc1C(=O)NCC1CCN(c', 'O=C(NC[C@H]1CN(c2ccc(N3CCOCC3=O)cc', 'Cc1ccc(C(=O)N2CCN(S(=O)(=O)c3c', 'N=C(N)NCCC[C@H](NC(=O)CNC(=O)CN[C@@H](C', 'O=C(NC[C@H]1CN(c2ccc(N3CCCC3=O)cc2']
# Better model found at epoch 1 with accuracy value: 0.8890343904495239.
# ['CCc1cc2c(N)nccc2cc1C[C@H](C(=N)N)N', 'N=C(N)CCN1C[C@H](c2ccc(F)c(F)c2)[C@@H](', 'CN(Cc1ccc2nc(C(=O)O)cc(O)c2c1)', 'O=C(Nc1ccc(Cl)cc1)[C@H]1CN(C(=O)C2C', 'CN(C)Cc=ccc(-c2ccc3c(c2)C[C@H]2[C@H]3[C@@H]']
# Better model found at epoch 2 with accuracy value: 0.8909457921981812.

# %%
learn_fn.save('fit2')

# %%
learn_fn.load('fit2');

# %%
learn_fn.unfreeze()

# %%
learn_fn.fit_one_cycle(5, slice(3e-3/(2.6**4),3e-3),cbs=cbs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.303783</td>
#       <td>0.322123</td>
#       <td>0.894422</td>
#       <td>1.380054</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.273967</td>
#       <td>0.298762</td>
#       <td>0.901872</td>
#       <td>1.348189</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.261271</td>
#       <td>0.286807</td>
#       <td>0.905022</td>
#       <td>1.332167</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.236019</td>
#       <td>0.279715</td>
#       <td>0.906988</td>
#       <td>1.322753</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.226389</td>
#       <td>0.278540</td>
#       <td>0.907112</td>
#       <td>1.321199</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# ['NCc1cccn1-c1ccc(N2CCOC(c3nc(CC', 'C[C@@H](C(=O)N1CCOCC1)N1CC[C@H](NS(=O)(', 'O=c1c2cc(Br)ccc2nc2n1C(=O)N(C1C', 'O=C(NC[C@H]1CN(c2ccc(N3CCOCC3)cc2)', 'O=C(Nc1ccc(N2CCOCC2=O)cc1)c1cc']
# Better model found at epoch 0 with accuracy value: 0.8944222331047058.
# ['CN(C)C(=N)c1ccc(NC(=O)c2nc(CN3', 'O=C(N[C@H]1CNC[C@H]1NC(=O)c1ccc(Cl)s1)c', 'C/C(=C(\\F)C(=O)Nc1ccc(-c2ccccc', 'CC[N+](C)(C)c1ccc(C(=O)NCc2ccccc2', 'COc1cccc(N/C(=C1\\C(=O)OC(C)(C)']
# Better model found at epoch 1 with accuracy value: 0.9018720984458923.
# ['CCOC(=O)COc1(-cc2c[nH]c3ccc(C(=N)', 'N=C(N)NCCC[C@@H](NC(=O)CNC(=O)[C@@H](CCc', 'O=C(N[C@H]1CCC[C@H]1NC(=O)c1cccc(Cl)c1)', 'Cc1c(F)c(Oc2cccc(C(=N)N)c2)nc(', 'CNC(=O)N1COC(C)(C(=O)Nc2ccc(-c']
# Better model found at epoch 2 with accuracy value: 0.9050219655036926.
# ['COc1ccc(N/C(=N\\C(=O)c2ccc(O)cc', 'CN(C)Cc1cccn1-c1ccc(N2C[C@H](CNC(=', 'COc1ccc(C(=O)NCC2CCN(c3ccncc3)', 'COC(=O)c1nn(-c2ccc3onc(N)c3c2)', 'N=C(N)NCCC(=O)Nc1ccc(N2CCCCC2=']
# Better model found at epoch 3 with accuracy value: 0.906988263130188.
# ['CC1CCN(Cc2csc(C(=O)Nc3ccc(Cl)cc', 'O=C(O)c1cnc2ccccc2c1Sc1ccc(Cl)c', 'N=C(N)c1ccc2c(c1)C(O)CC2(C(F)(', 'O=C(NC[C@H]1CN(c2ccc(N3CCOCC3=O)cc', 'COc1ccc(C2Oc3ccccc3N(CCCCCN3C(']
# Better model found at epoch 4 with accuracy value: 0.9071122407913208.

# %%
learn_fn.save('fit3')
learn_fn.save_encoder('encoder')

# %%
learn_fn.export()

# %%
learn_fn_inf = load_learner('/content/LM/fxa_finetune/export.pkl')

# %%
from tqdm.notebook import tqdm

# %%
mols_fn =[] 
for i in range(100):
  mols_fn.append(sampler_test(model=learn_fn_inf,text='',temperature=0.7,max_size=120)) 
  if i != 0 and i % 10 == 0:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90

# %% [markdown]
# How many **valid** molecules did we generate?

# %%
valid_mols = [x for x in mols_fn if MolFromSmiles(x)]
print('Percentage of valid SMILES:{:.2f}%'.format(100*len(valid_mols)/len(mols_fn)))
# Out:
# Percentage of valid SMILES:100.00%

# %% [markdown]
# How many molecules are **novel** (i.e., not present on the training set)?

# %%
novel_mols = set.difference(set(valid_mols),set(fxa.canonical_smiles))
print('Percentage of novel SMILES:{:.2f}%'.format(100*len(novel_mols)/len(valid_mols)))
# Out:
# Percentage of novel SMILES:44.00%

# %% [markdown]
# And how many unique SMILES do we have?

# %%
unique_mols = set(valid_mols)
print('Percentage of unique SMILES:{:.2f}%'.format(100*len(unique_mols)/len(valid_mols)))
# Out:
# Percentage of unique SMILES:94.00%

# %%
MolsToGridImage(mols = list(map(MolFromSmiles,unique_mols)),maxMols=50,molsPerRow=5,subImgSize=(300,300))
# Out:
# /usr/local/lib/python3.7/site-packages/rdkit/Chem/Draw/IPythonConsole.py:188: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   % (maxMols))
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1500x3000 at 0x7F3E61A5D160>
